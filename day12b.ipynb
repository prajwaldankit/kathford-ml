# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
marks = pd.Series([40,50,25], index=["english", "maths", "cs"])

print(marks)
type(marks)
# Out:
# english    40
# maths      50
# cs         25
# dtype: int64
# pandas.Series

# %%
marks["english"]
# Out:
# np.int64(40)

# %%
data = {
    "name": ["Ankit", "Prajwal", "Jenish"],
    "marks":[40,25,23]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  marks
# 0    Ankit     40
# 1  Prajwal     25
# 2   Jenish     23

# %%
df.shape
# Out:
# (3, 2)

# %%
df = pd.read_csv("data.csv")
print(df.tail())
# Out:
#              x          y
# 995  17.726727  46.571407
# 996  49.429735  91.084734
# 997   1.318091  16.927206
# 998  18.455390  50.270771
# 999   4.357072  -9.202795

# %%
df.columns
# Out:
# Index(['x', 'y'], dtype='str')

# %%
print(df['y'])
# Out:
# 0      128.780163
# 1       37.624932
# 2       15.559688
# 3       97.565079
# 4       14.252318
#           ...
# 995     46.571407
# 996     91.084734
# 997     16.927206
# 998     50.270771
# 999     -9.202795
# Name: y, Length: 1000, dtype: float64
