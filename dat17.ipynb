# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
X = np.array(df["YearsExperience"]).reshape(-1,1)
y = np.array(df["Salary"]).reshape(-1,1)
plt.scatter(X, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# [[6. ]
#  [5.2]
#  [9.7]
#  [4.2]
#  [6.1]
#  [3.8]
#  [4.6]
#  [3. ]
#  [8.3]
#  [3.3]]
# array([[ 81313.59450769],
#        [ 73828.24602269],
#        [115933.33125085],
#        [ 64471.56041643],
#        [ 82249.26306832],
#        [ 60728.88617392],
#        [ 68214.23465893],
#        [ 53243.53768892],
#        [102833.97140209],
#        [ 56050.54337079]])

# %%
plt.scatter(X,y)
plt.plot(X, model.predict(X), color="red")
plt.xlabel("Years of Experience")
plt.xlabel("Salary")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = model.predict(X_test)
print(y_pred, y_test)
# Out:
# [[ 81313.59450769]
#  [ 73828.24602269]
#  [115933.33125085]
#  [ 64471.56041643]
#  [ 82249.26306832]
#  [ 60728.88617392]
#  [ 68214.23465893]
#  [ 53243.53768892]
#  [102833.97140209]
#  [ 56050.54337079]] [[ 81364.]
#  [ 66030.]
#  [112636.]
#  [ 57082.]
#  [ 93941.]
#  [ 57190.]
#  [ 61112.]
#  [ 56643.]
#  [113813.]
#  [ 64446.]]

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("mae", mae)
print("mse", mse)
print("r2", r2)
# Out:
# mae 6364.234848500715
# mse 52853444.82231071
# r2 0.8866245750681764
