# %% [markdown]
# ## 🧩 Task 1: Smart Number Analyzer
# **Concepts:** input, conditionals, loops, operators
#
# Write a program that:
# 1. Takes an integer input from the user
# 2. Prints:
#    - Whether it is **even or odd**
#    - Whether it is **prime**
#    - The **sum of its digits**
#
# ### Example:
# ```console
# Enter number: 29
# Odd
# Prime
# Sum of digits: 11
# ```
#
# ### Constraints:
# - Do NOT use any external libraries
# - Prime logic must be implemented manually

# %% [markdown]
# ## 🧩 Task 2: List Cleaner & Analyzer
# **Concepts:** lists, loops, conditionals
#
# Given a list:
# ```python
# data = [12, -3, 45, 0, -8, 23, 45, 12]
# ```
#
# ### Perform the following:
#
# - Remove all negative numbers
# - Remove duplicates (without using set)
#
# ### Print:
# - Cleaned list
# - Maximum and minimum values
# - Second largest number

# %% [markdown]
# ## 🧩 Task 3: String Compression Tool
#
# Concepts: strings, loops, counting patterns
#
# Write a program that compresses a string using character counts.
#
# ### Example:
#
# ```console
# Input: aaabbcaaa
# Output: a3b2c1a3
# ```
#
# ### Rules:
# - Case-sensitive
# - Do NOT use libraries like collections
# - Maintain order
#
# ### Edge Case:
# ```console
# Input: abc
# Output: a1b1c1
# ```

# %% [markdown]
# ## 🧩 Task 4: Student Marks Manager
#
# Concepts: dictionaries, loops, functions
#
# Create a system to:
#
# Store student names and their marks (3 subjects)
# Compute:
# Average marks per student
# Grade:
# - A (>=80)
# - B (60–79)
# - C (40–59)
# - F (<40)
#
# ### Output Format:
# ```console
# Name: Ram
# Marks: [80, 70, 90]
# Average: 80.0
# Grade: A
# ```
#
# ### Requirements:
# - Use at least one function
# - Store data in a dictionary

# %% [markdown]
# ## 🧩 Task 5: File-Based Word Analyzer
#
# Concepts: file handling, strings, dictionaries
#
# Given a text file (sample.txt), write a program to:
#
# Count total number of words
# Count frequency of each word
# Print:
# Most frequent word
# Words that appear only once
# Constraints:
# - Ignore punctuation manually
# - Case-insensitive ("Word" == "word")

# %% [markdown]
# ## 🧩 Task 6: Mini CLI To-Do App
#
# Concepts: loops, functions, lists, user interaction
#
# ### Build a simple command-line To-Do system:
#
# ### Features:
# - Add task
# - View tasks
# - Mark task as done
# - Delete task
# - Exit
#
# ### Example Menu:
# 1. Add Task
# 2. View Tasks
# 3. Mark Done
# 4. Delete Task
# 5. Exit
#
# ### Requirements:
# - Store tasks in a list
# - Use functions for each feature
# - Keep running until user exits
#
# ### Bonus (Optional):
# - Save/load tasks from a file
