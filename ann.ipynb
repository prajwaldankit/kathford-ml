# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
with open("t10k-images.idx3-ubyte", "rb") as f:
    f.read(16)
    images = np.frombuffer(f.read(), dtype=np.uint8)

images = images.reshape(-1, 28 * 28)

# %%
with open("t10k-labels.idx1-ubyte", "rb") as f:
    f.read(8)
    labels = np.frombuffer(f.read(), dtype=np.uint8)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    images,
    labels,
    test_size=0.2,
    random_state=42
)

# %%
model = MLPClassifier(
    hidden_layer_sizes=(64,),
    max_iter=20,
    random_state=42
)

# %%
model.fit(X_train, y_train)
# Out:
# /home/ankit/class/kathford_march26/venv/lib/python3.14/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(64,), max_iter=20, random_state=42)

# %%
y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)


image = X_test[0]

prediction = model.predict([image])

print("Predicted Digit:", prediction[0])

plt.imshow(image.reshape(28, 28), cmap="gray")
plt.title(f"Prediction: {prediction[0]}")
plt.show()
# Out:
# Accuracy: 0.8995
# Predicted Digit: 6
