# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.arange(-10,11)
y = x ** 2 + 3

# plt.plot(x,y)
sns.lineplot(x=x, y=y)
plt.show()

# %%
x= np.random.randn(1000)
sns.histplot(x=x)

plt.show()

# %%
x = np.linspace(0,50,400)
y = x * 3 + np.random.rand(400)* 40

sns.scatterplot(x= x, y = y)

plt.show()

# %%
data = np.random.randn(1000)

sns.kdeplot(data)

plt.show()

# %%
sns.boxplot(data, orient='h')
plt.show()

# %%
data = np.random.rand(5,5)
print(data)

sns.heatmap(data, annot=True)
plt.show()
# Out:
# [[0.92362128 0.82699221 0.86504542 0.5719285  0.5476899 ]
#  [0.273149   0.41329436 0.89120387 0.13906408 0.09452278]
#  [0.62226372 0.66357691 0.75236693 0.39636489 0.24261789]
#  [0.30896088 0.37008268 0.4021696  0.95752792 0.01837018]
#  [0.60500459 0.8795759  0.40829103 0.70559877 0.6598787 ]]
