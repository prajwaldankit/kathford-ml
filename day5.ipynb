# %% [markdown]
# - error handling
# - modules

# %%
def add(a,b):
    return a + b 

def multiply(a,b):
    return a * b

def substract(a,b):
    return a - b

def divide(a,b):
    return a / b

# %%
import math
math.sin(12)
# Out:
# -0.5365729180004349

# %% [markdown]
# - Circular import

# %%
def write_error_log(filename, error):
    with open(filename, "a") as log_file:
        log_file.write(error + "\n")

# %%
try:
    num = int(input("enter a number"))
    print(1/num)
except ZeroDivisionError:
    print("cant divide by zero")
    write_error_log("error.log","cant divide by zero")
except ValueError:
    print("that was not a valid input")
except Exception as e:
    print("Unhandled Error", e)
finally:
    print("hello")
# Out:
# cant divide by zero
# hello
